# %% [markdown]
# # QoS Prediction Challenge

# %% [markdown]
# ## 0. Préalable

# %% [markdown]
# ### Importation des modules

# %%
# numerical calculation
import numpy as np
# dataframe
import pandas as pd
# vizualisation
import matplotlib.pyplot as plt
import seaborn as sns
# models
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
# splitting
from sklearn.model_selection import train_test_split
# encoding
from sklearn.preprocessing import OrdinalEncoder
# metrics
from sklearn.metrics import mean_squared_error
# utils
import random
from datetime import datetime as dt
# saving model
import joblib

# %%
# Set seed for reproducability
SEED = 0
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ### Chargement du jeu de données

# %%
DATA_PATH = 'data/' # repertoire des données
train = pd.read_csv(DATA_PATH + 'Train.csv') # ensemble d'apprentissage
test = pd.read_csv(DATA_PATH + 'Test.csv') # ensemble de test
sample_submission = pd.read_csv(DATA_PATH + 'SampleSubmission.csv') # exemple de soumission
variable_definitions = pd.read_csv(DATA_PATH + 'VariableDefinitions.csv') # definition des variables

# %%
train.head(3)
# Out:
#               id   timestamp device  PCell_RSRP_max  PCell_RSRQ_max  \
# 0  Id_qt2qn56050  1624367008    pc1      -84.498750      -14.586875
# 1  Id_f1zf07cwb6  1624372465    pc3      -86.818125      -11.982500
# 2  Id_uoxdz7di5b  1624371871    pc3     -101.916250      -13.257500
#
#    PCell_RSSI_max  PCell_SNR_max  PCell_Downlink_Num_RBs  \
# 0      -49.855625         16.457                 35076.0
# 1      -54.838125         16.674                 42704.0
# 2      -71.241250          9.392                 36017.0
#
#    PCell_Downlink_Average_MCS  PCell_Downlink_bandwidth_MHz  ...  dewPoint  \
# 0                        23.0                          20.0  ...     13.86
# 1                        24.0                          20.0  ...     14.52
# 2                        22.0                          20.0  ...     14.71
#
#    humidity  pressure  windSpeed  cloudCover  uvIndex  visibility  \
# 0      0.62    1013.6       2.39        0.95      4.0      16.093
# 1      0.59    1013.5       2.29        0.82      3.0      16.093
# 2      0.61    1013.8       2.13        0.82      3.0      16.093
#
#    Traffic Jam Factor         area      target
# 0             0.38979  Residential  51500000.0
# 1             3.78322  Residential  50300000.0
# 2             2.08425  Residential  16500000.0
#
# [3 rows x 41 columns]

# %%
test.head(3)
# Out:
#               id   timestamp device  PCell_RSRP_max  PCell_RSRQ_max  \
# 0  Id_ln0e0hfrgx  1624374179    pc2      -97.121875      -12.923750
# 1  Id_svf7nz9fxv  1624366264    pc4      -65.202500       -9.944375
# 2  Id_ww2mh07gwj  1624375795    pc2      -79.298125      -17.468750
#
#    PCell_RSSI_max  PCell_SNR_max  PCell_Downlink_Num_RBs  \
# 0      -87.554375         13.293                 39276.0
# 1      -35.501875         21.823                 39566.0
# 2      -74.823750         24.114                 41900.0
#
#    PCell_Downlink_Average_MCS  PCell_Downlink_bandwidth_MHz  ...  \
# 0                        24.0                            20  ...
# 1                        25.0                            20  ...
# 2                        27.0                            20  ...
#
#    apparentTemperature  dewPoint  humidity  pressure  windSpeed  cloudCover  \
# 0                23.05     14.55      0.59    1013.6       2.27        0.83
# 1                21.56     13.92      0.62    1013.6       2.42        0.95
# 2                22.93     14.65      0.60    1013.5       2.26        0.85
#
#    uvIndex  visibility  Traffic Jam Factor    area
# 0      3.0      16.093             3.07702  Avenue
# 1      4.0      16.093             0.66000    Park
# 2      3.0      16.093             2.49330    Park
#
# [3 rows x 40 columns]

# %% [markdown]
# Variables identifiant et objectif

# %% [markdown]
# La target de notre dataset est la variable **target**.

# %%
ID = 'id'
TARGET = 'target'

# %% [markdown]
# ## 1. Analyse exploratoire

# %% [markdown]
# ### 1.1. Analyse de la forme

# %% [markdown]
# Dimension du dataset

# %%
# Let’s observe the shape of our datasets.
print('Dimension du train set :', train.shape)
print('Dimension du test set :', test.shape)
# Out:
# Dimension du train set : (34274, 41)
# Dimension du test set : (18243, 40)

# %% [markdown]
# Ratio entre train et test sets

# %%
test.shape[0] / train.shape[0] * 100
# Out:
# 53.2269358697555

# %% [markdown]
# Types des variables

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34274 entries, 0 to 34273
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            34274 non-null  object
#  1   timestamp                     34274 non-null  int64
#  2   device                        34274 non-null  object
#  3   PCell_RSRP_max                34274 non-null  float64
#  4   PCell_RSRQ_max                34274 non-null  float64
#  5   PCell_RSSI_max                34274 non-null  float64
#  6   PCell_SNR_max                 34274 non-null  float64
#  7   PCell_Downlink_Num_RBs        34274 non-null  float64
#  8   PCell_Downlink_Average_MCS    34274 non-null  float64
#  9   PCell_Downlink_bandwidth_MHz  33207 non-null  float64
#  10  PCell_Cell_Identity           33207 non-null  float64
#  11  PCell_freq_MHz                34274 non-null  float64
#  12  SCell_RSRP_max                19012 non-null  float64
#  13  SCell_RSRQ_max                19012 non-null  float64
#  14  SCell_RSSI_max                19012 non-null  float64
#  15  SCell_SNR_max                 19012 non-null  float64
#  16  SCell_Downlink_Num_RBs        18335 non-null  float64
#  17  SCell_Downlink_Average_MCS    18335 non-null  float64
#  18  SCell_Downlink_bandwidth_MHz  13425 non-null  float64
#  19  SCell_Cell_Identity           13425 non-null  float64
#  20  SCell_freq_MHz                19012 non-null  float64
#  21  operator                      34274 non-null  int64
#  22  Latitude                      34274 non-null  float64
#  23  Longitude                     34274 non-null  float64
#  24  Altitude                      34267 non-null  float64
#  25  speed_kmh                     34274 non-null  float64
#  26  COG                           34274 non-null  float64
#  27  precipIntensity               34274 non-null  float64
#  28  precipProbability             34274 non-null  float64
#  29  temperature                   34274 non-null  float64
#  30  apparentTemperature           34274 non-null  float64
#  31  dewPoint                      34274 non-null  float64
#  32  humidity                      34274 non-null  float64
#  33  pressure                      34274 non-null  float64
#  34  windSpeed                     34274 non-null  float64
#  35  cloudCover                    34274 non-null  float64
#  36  uvIndex                       34274 non-null  float64
#  37  visibility                    34274 non-null  float64
#  38  Traffic Jam Factor            33946 non-null  float64
#  39  area                          34274 non-null  object
#  40  target                        34274 non-null  float64
# dtypes: float64(36), int64(2), object(3)
# memory usage: 10.7+ MB

# %% [markdown]
# Analyse des variables qualitatives

# %%
train.select_dtypes(include='object').describe()
# Out:
#                    id device   area
# count           34274  34274  34274
# unique          34274      2      5
# top     Id_qt2qn56050    pc1   Park
# freq                1  19505  13438

# %%
for colonne in list(train.columns):
    print(colonne)
    print(train[colonne].value_counts(), '\n')
# Out:
# id
# Id_qt2qn56050    1
# Id_ojvi2rdfpw    1
# Id_edb0fu4jap    1
# Id_9ftaq07qu0    1
# Id_65drpv9yul    1
#                 ..
# Id_ge28z7rjds    1
# Id_29npmuawod    1
# Id_cgkdhn72cf    1
# Id_ykdq0weq3r    1
# Id_6ovc5xvg0o    1
# Name: id, Length: 34274, dtype: int64
#
# timestamp
# 1624552037    2
# 1624548733    2
# 1624552672    2
# 1624348630    2
# 1624552476    2
#              ..
# 1624356799    1
# 1624545345    1
# 1624348818    1
# 1624373680    1
# 1624376571    1
# Name: timestamp, Length: 27373, dtype: int64
#
# device
# pc1    19505
# pc3    14769
# Name: device, dtype: int64
#
# PCell_RSRP_max
# -85.495000    7
# -86.025000    7
# -94.078125    6
# -88.596875    6
# -85.829375    5
#              ..
# -95.941250    1
# -78.746875    1
# -92.836875    1
# -84.349375    1
# -97.323125    1
# Name: PCell_RSRP_max, Length: 27457, dtype: int64
#
# PCell_RSRQ_max
# -12.220625    17
# -12.361250    15
# -12.253125    14
# -12.194375    13
# -12.323750    13
#               ..
# -17.967500     1
# -18.084478     1
# -12.055707     1
# -18.013125     1
# -17.122500     1
# Name: PCell_RSRQ_max, Length: 14742, dtype: int64
#
# PCell_RSSI_max
# -52.813750    7
# -57.362500    6
# -52.041875    6
# -62.118750    6
# -52.789375    6
#              ..
# -79.214375    1
# -35.916875    1
# -66.823750    1
# -46.220000    1
# -51.610000    1
# Name: PCell_RSSI_max, Length: 27142, dtype: int64
#
# PCell_SNR_max
# 18.120    4
# 13.379    3
# 18.243    3
# 13.317    3
# 20.610    3
#          ..
# 4.459     1
# 19.550    1
# 16.806    1
# 8.220     1
# 7.869     1
# Name: PCell_SNR_max, Length: 33560, dtype: int64
#
# PCell_Downlink_Num_RBs
# 94980.0    7
# 93988.0    7
# 93940.0    7
# 95492.0    7
# 95104.0    7
#           ..
# 71083.0    1
# 38461.0    1
# 60769.0    1
# 37119.0    1
# 50346.0    1
# Name: PCell_Downlink_Num_RBs, Length: 25934, dtype: int64
#
# PCell_Downlink_Average_MCS
# 24.0    2805
# 23.0    2790
# 22.0    2500
# 21.0    2467
# 20.0    2359
# 25.0    2235
# 19.0    2172
# 18.0    2062
# 17.0    1901
# 27.0    1821
# 16.0    1664
# 26.0    1617
# 15.0    1486
# 28.0    1188
# 14.0    1170
# 13.0    1081
# 12.0     785
# 11.0     574
# 10.0     457
# 9.0      383
# 8.0      270
# 7.0      192
# 6.0      132
# 5.0       87
# 4.0       37
# 2.0       16
# 3.0       15
# 0.0        4
# 1.0        4
# Name: PCell_Downlink_Average_MCS, dtype: int64
#
# PCell_Downlink_bandwidth_MHz
# 20.0    28278
# 15.0     4849
# 5.0        80
# Name: PCell_Downlink_bandwidth_MHz, dtype: int64
#
# PCell_Cell_Identity
# 2568970.0     1722
# 26358784.0     993
# 26358785.0     835
# 26369024.0     799
# 40782336.0     713
#               ...
# 51839253.0       2
# 2838294.0        2
# 3289866.0        1
# 4002325.0        1
# 4002319.0        1
# Name: PCell_Cell_Identity, Length: 213, dtype: int64
#
# PCell_freq_MHz
# 1800.0    24607
# 2000.0     5423
# 2600.0     4164
# 900.0        80
# Name: PCell_freq_MHz, dtype: int64
#
# SCell_RSRP_max
# -93.906250    5
# -94.746875    5
# -94.755000    5
# -87.634375    5
# -94.627500    5
#              ..
# -79.234375    1
# -94.414402    1
# -78.458750    1
# -77.820000    1
# -86.400000    1
# Name: SCell_RSRP_max, Length: 16091, dtype: int64
#
# SCell_RSRQ_max
# -30.000000    61
# -9.765625     14
# -9.694375     12
# -9.726250     12
# -10.114375    12
#               ..
# -13.995625     1
# -14.695625     1
# -12.008125     1
# -11.057990     1
# -13.227500     1
# Name: SCell_RSRQ_max, Length: 9467, dtype: int64
#
# SCell_RSSI_max
# -61.385625    6
# -61.943750    5
# -61.756250    5
# -61.966250    5
# -63.705625    4
#              ..
# -37.961250    1
# -62.665000    1
# -55.518125    1
# -46.236250    1
# -52.973125    1
# Name: SCell_RSSI_max, Length: 16061, dtype: int64
#
# SCell_SNR_max
# 15.956    3
# 15.926    3
# 15.697    3
# 15.306    3
# 13.088    3
#          ..
# 12.543    1
# 25.687    1
# 8.330     1
# 15.112    1
# 13.028    1
# Name: SCell_SNR_max, Length: 18674, dtype: int64
#
# SCell_Downlink_Num_RBs
# 96136.0    11
# 97356.0    10
# 48404.0    10
# 95268.0    10
# 94328.0     9
#            ..
# 73110.0     1
# 26160.0     1
# 91398.0     1
# 72076.0     1
# 41810.0     1
# Name: SCell_Downlink_Num_RBs, Length: 11127, dtype: int64
#
# SCell_Downlink_Average_MCS
# 16.0    1504
# 20.0    1379
# 21.0    1321
# 15.0    1311
# 17.0    1250
# 22.0    1227
# 18.0    1222
# 19.0    1213
# 23.0    1036
# 24.0     942
# 14.0     794
# 25.0     701
# 27.0     684
# 13.0     650
# 28.0     607
# 26.0     542
# 12.0     509
# 11.0     362
# 10.0     318
# 9.0      238
# 8.0      163
# 7.0       85
# 5.0       61
# 6.0       60
# 4.0       51
# 2.0       30
# 0.0       27
# 3.0       21
# 1.0       20
# 29.0       3
# 30.0       2
# 31.0       2
# Name: SCell_Downlink_Average_MCS, dtype: int64
#
# SCell_Downlink_bandwidth_MHz
# 20.0    13419
# 15.0        6
# Name: SCell_Downlink_bandwidth_MHz, dtype: int64
#
# SCell_Cell_Identity
# 2568967.0     1582
# 26358784.0     712
# 33802248.0     647
# 33802242.0     621
# 26349061.0     474
#               ...
# 26356997.0       5
# 2826249.0        4
# 51447561.0       3
# 3289863.0        2
# 26357760.0       1
# Name: SCell_Cell_Identity, Length: 74, dtype: int64
#
# SCell_freq_MHz
# 2600.0    17608
# 1800.0     1402
# 2000.0        2
# Name: SCell_freq_MHz, dtype: int64
#
# operator
# 1    19505
# 2    14769
# Name: operator, dtype: int64
#
# Latitude
# 52.491645    517
# 52.491647    309
# 52.491643    264
# 52.491648    167
# 52.515122    139
#             ...
# 52.491438      1
# 52.492907      1
# 52.496980      1
# 52.506995      1
# 52.509512      1
# Name: Latitude, Length: 10527, dtype: int64
#
# Longitude
# 13.304608    330
# 13.304610    221
# 13.355713    214
# 13.304605    166
# 13.304613    137
#             ...
# 13.291112      1
# 13.294017      1
# 13.334047      1
# 13.349887      1
# 13.325867      1
# Name: Longitude, Length: 17791, dtype: int64
#
# Altitude
# 35.5    381
# 38.5    369
# 33.3    363
# 42.4    326
# 36.5    317
#        ...
# 74.5      1
# 76.9      1
# 60.1      1
# 74.4      1
# 72.0      1
# Name: Altitude, Length: 528, dtype: int64
#
# speed_kmh
# 0.0000     12637
# 35.3732      119
# 40.9292      112
# 12.2232      110
# 26.8540      109
#            ...
# 62.7828        1
# 76.1172        1
# 77.7840        1
# 74.4504        1
# 78.8952        1
# Name: speed_kmh, Length: 408, dtype: int64
#
# COG
# 159.0    1336
# 83.8      765
# 84.1      717
# 84.0      599
# 83.9      547
#          ...
# 44.8        1
# 74.6        1
# 161.8       1
# 132.3       1
# 101.5       1
# Name: COG, Length: 2931, dtype: int64
#
# precipIntensity
# 0.0000    3380
# 0.0132    1628
# 0.0652    1092
# 0.2166     840
# 0.2148     747
#           ...
# 0.0459      21
# 0.3042       9
# 0.2995       2
# 0.0245       1
# 0.0409       1
# Name: precipIntensity, Length: 145, dtype: int64
#
# precipProbability
# 0.01    8483
# 0.32    4724
# 0.04    3618
# 0.02    3461
# 0.00    3380
# 0.46    2768
# 0.44    1400
# 0.23    1307
# 0.47    1001
# 0.45     949
# 0.24     936
# 0.22     795
# 0.43     773
# 0.31     677
# 0.33       2
# Name: precipProbability, dtype: int64
#
# temperature
# 18.15    1854
# 18.65    1635
# 22.98    1597
# 18.67    1569
# 18.63    1569
#          ...
# 22.93      31
# 21.60      26
# 19.34      24
# 19.26      21
# 19.30       1
# Name: temperature, Length: 85, dtype: int64
#
# apparentTemperature
# 18.15    1854
# 18.65    1635
# 22.98    1597
# 18.67    1569
# 18.63    1569
#          ...
# 22.93      31
# 21.60      26
# 19.34      24
# 19.26      21
# 19.30       1
# Name: apparentTemperature, Length: 85, dtype: int64
#
# dewPoint
# 13.67    1650
# 14.52    1597
# 14.06    1548
# 13.83    1449
# 14.71    1276
#          ...
# 13.35      33
# 14.00      13
# 13.76      11
# 13.52       7
# 14.20       4
# Name: dewPoint, Length: 95, dtype: int64
#
# humidity
# 0.72    6035
# 0.71    4418
# 0.73    3974
# 0.62    3823
# 0.77    3618
# 0.70    2876
# 0.59    2720
# 0.57    2593
# 0.61    2209
# 0.74    1130
# 0.60     378
# 0.69     360
# 0.63     123
# 0.58      13
# 0.55       4
# Name: humidity, dtype: int64
#
# pressure
# 1017.9    7940
# 1017.7    3769
# 1011.9    3618
# 1013.7    3596
# 1012.5    3236
# 1017.4    3122
# 1013.6    2910
# 1013.5    2480
# 1013.8    2398
# 1018.0     501
# 1013.9     479
# 1012.2     225
# Name: pressure, dtype: int64
#
# windSpeed
# 4.07    3154
# 2.30    2850
# 2.16    2577
# 2.29    2144
# 1.97    2071
# 2.42    2012
# 2.15    1744
# 4.06    1706
# 2.43    1484
# 2.17    1460
# 2.12    1331
# 2.13     855
# 2.14     852
# 2.26     692
# 2.22     673
# 2.44     635
# 2.27     593
# 4.08     590
# 2.40     578
# 2.41     504
# 4.05     473
# 1.98     456
# 2.19     449
# 2.31     446
# 4.10     445
# 1.99     434
# 2.39     420
# 4.09     381
# 2.45     329
# 2.21     260
# 2.18     249
# 2.20     241
# 2.46     229
# 4.23     162
# 2.35     159
# 2.11     140
# 2.36     139
# 1.96      77
# 4.25      63
# 4.11      61
# 2.25      53
# 2.23      45
# 4.04      43
# 2.37      13
# 2.24       1
# 4.12       1
# Name: windSpeed, dtype: int64
#
# cloudCover
# 0.99    7972
# 1.00    7360
# 0.97    3870
# 0.95    3292
# 0.96    3040
# 0.82    2867
# 0.76    2597
# 0.83    1511
# 0.84    1038
# 0.85     364
# 0.98     169
# 0.86     106
# 0.94      88
# Name: cloudCover, dtype: int64
#
# uvIndex
# 3.0    12542
# 2.0     8000
# 1.0     6891
# 4.0     6841
# Name: uvIndex, dtype: int64
#
# visibility
# 16.093    34274
# Name: visibility, dtype: int64
#
# Traffic Jam Factor
# 3.14159    4202
# 0.00000     793
# 0.28864     198
# 8.49000     196
# 2.89119     190
#            ...
# 0.60523       1
# 0.94235       1
# 2.40422       1
# 3.15836       1
# 1.24295       1
# Name: Traffic Jam Factor, Length: 1817, dtype: int64
#
# area
# Park           13438
# Residential    10407
# Avenue          6889
# Highway         3397
# Tunnel           143
# Name: area, dtype: int64
#
# target
# 101000000.0    103
# 141000000.0     94
# 102000000.0     88
# 107000000.0     87
# 103000000.0     87
#               ...
# 6000000.0        1
# 1680000.0        1
# 5810000.0        1
# 7060000.0        1
# 2580000.0        1
# Name: target, Length: 1789, dtype: int64

# %%
for colonne in list(test.columns):
    print(colonne)
    print(test[colonne].value_counts(), '\n')
# Out:
# id
# Id_ln0e0hfrgx    1
# Id_9jsf9s9wsf    1
# Id_e4m1soef49    1
# Id_fkjjdyvn30    1
# Id_1cgwmj2yyf    1
#                 ..
# Id_jwrtpqx3pq    1
# Id_s98mtaqycr    1
# Id_8vtkaopvmq    1
# Id_5oxn0xvlj4    1
# Id_e2duej4gcq    1
# Name: id, Length: 18243, dtype: int64
#
# timestamp
# 1624348977    2
# 1624348342    2
# 1624348345    2
# 1624349366    2
# 1624348232    2
#              ..
# 1624356197    1
# 1624372450    1
# 1624374512    1
# 1624357087    1
# 1624369388    1
# Name: timestamp, Length: 16455, dtype: int64
#
# device
# pc4    9473
# pc2    8770
# Name: device, dtype: int64
#
# PCell_RSRP_max
# -88.421250     6
# -88.391250     5
# -95.380625     5
# -95.298750     4
# -88.218750     4
#               ..
# -106.062500    1
# -73.106250     1
# -96.173750     1
# -105.715000    1
# -103.098125    1
# Name: PCell_RSRP_max, Length: 15852, dtype: int64
#
# PCell_RSRQ_max
# -12.723125    9
# -12.738750    9
# -12.795625    9
# -12.310000    9
# -12.815625    9
#              ..
# -15.130625    1
# -13.857500    1
# -13.546250    1
# -13.693125    1
# -15.954375    1
# Name: PCell_RSRQ_max, Length: 10482, dtype: int64
#
# PCell_RSSI_max
# -93.556875    7
# -93.538125    7
# -93.521875    7
# -93.557500    7
# -93.522500    6
#              ..
# -86.240625    1
# -66.300625    1
# -89.613125    1
# -58.100000    1
# -67.630625    1
# Name: PCell_RSSI_max, Length: 15711, dtype: int64
#
# PCell_SNR_max
#  16.870    3
#  20.034    3
#  19.872    3
#  25.201    2
#  16.536    2
#           ..
# -1.418     1
#  17.001    1
#  4.639     1
#  14.756    1
#  8.063     1
# Name: PCell_SNR_max, Length: 17987, dtype: int64
#
# PCell_Downlink_Num_RBs
# 45501.0    9
# 99816.0    8
# 38391.0    6
# 95400.0    6
# 97748.0    6
#           ..
# 43056.0    1
# 53261.0    1
# 95096.0    1
# 42550.0    1
# 37837.0    1
# Name: PCell_Downlink_Num_RBs, Length: 14819, dtype: int64
#
# PCell_Downlink_Average_MCS
# 27.0    1919
# 28.0    1298
# 19.0    1092
# 18.0    1061
# 16.0    1050
# 20.0    1044
# 22.0    1023
# 21.0    1000
# 23.0     999
# 17.0     983
# 15.0     963
# 14.0     890
# 24.0     871
# 25.0     703
# 26.0     658
# 13.0     606
# 12.0     494
# 11.0     387
# 10.0     335
# 9.0      254
# 8.0      201
# 7.0      142
# 6.0       83
# 5.0       77
# 4.0       68
# 3.0       25
# 2.0       13
# 1.0        2
# 0.0        1
# Name: PCell_Downlink_Average_MCS, dtype: int64
#
# PCell_Downlink_bandwidth_MHz
# 20    17781
# 15      432
# 5        30
# Name: PCell_Downlink_bandwidth_MHz, dtype: int64
#
# PCell_Cell_Identity
# 2568970.0     1565
# 3998479.0      823
# 30828801.0     818
# 3499534.0      517
# 26947074.0     449
#               ...
# 40812803.0       3
# 4002319.0        2
# 51502601.0       2
# 2819861.0        1
# 2828565.0        1
# Name: PCell_Cell_Identity, Length: 134, dtype: int64
#
# PCell_freq_MHz
# 1800.0    14509
# 2600.0     3271
# 2000.0      433
# 900.0        30
# Name: PCell_freq_MHz, dtype: int64
#
# SCell_RSRP_max
# -100.162500    5
# -100.666875    5
# -100.918125    4
# -101.958125    4
# -101.228750    4
#               ..
# -81.706250     1
# -100.080625    1
# -97.487500     1
# -95.828750     1
# -97.408750     1
# Name: SCell_RSRP_max, Length: 8710, dtype: int64
#
# SCell_RSRQ_max
# -9.825625     10
# -9.590625      8
# -9.708750      8
# -10.096875     8
# -9.863125      8
#               ..
# -16.573125     1
# -12.191250     1
# -12.729167     1
# -8.929375      1
# -9.316875      1
# Name: SCell_RSRQ_max, Length: 6097, dtype: int64
#
# SCell_RSSI_max
# -89.498125    4
# -89.082500    4
# -89.114375    4
# -89.448750    4
# -91.316875    4
#              ..
# -73.420000    1
# -64.374375    1
# -91.838125    1
# -68.402500    1
# -67.977500    1
# Name: SCell_RSSI_max, Length: 8836, dtype: int64
#
# SCell_SNR_max
# 14.640000    2
# 13.593000    2
# 7.055000     2
# 15.745000    2
# 8.078000     2
#             ..
# 15.142000    1
# 9.869307     1
# 16.575000    1
# 13.696000    1
# 14.815000    1
# Name: SCell_SNR_max, Length: 9541, dtype: int64
#
# SCell_Downlink_Num_RBs
# 48184.0    9
# 11.0       9
# 48956.0    8
# 47860.0    7
# 48656.0    7
#           ..
# 47422.0    1
# 30948.0    1
# 50690.0    1
# 38464.0    1
# 37665.0    1
# Name: SCell_Downlink_Num_RBs, Length: 6588, dtype: int64
#
# SCell_Downlink_Average_MCS
# 16.0    873
# 15.0    813
# 19.0    707
# 17.0    675
# 18.0    673
# 14.0    663
# 20.0    598
# 21.0    453
# 22.0    422
# 13.0    398
# 23.0    391
# 24.0    290
# 12.0    282
# 11.0    213
# 28.0    213
# 27.0    179
# 10.0    165
# 25.0    157
# 9.0     148
# 26.0    147
# 8.0     142
# 7.0      84
# 6.0      60
# 5.0      37
# 4.0      32
# 3.0      23
# 1.0      21
# 0.0      16
# 2.0      12
# 29.0      3
# 30.0      2
# 31.0      1
# Name: SCell_Downlink_Average_MCS, dtype: int64
#
# SCell_Downlink_bandwidth_MHz
# 20.0    4682
# 15.0     178
# Name: SCell_Downlink_bandwidth_MHz, dtype: int64
#
# SCell_Cell_Identity
# 2568967.0     1494
# 30828803.0     541
# 33802248.0     332
# 30829312.0     256
# 26947075.0     230
# 26358784.0     221
# 51842565.0     193
# 29127681.0     190
# 51709204.0     178
# 2826246.0      166
# 29127684.0     165
# 2843405.0      163
# 33802242.0     156
# 29127685.0     112
# 2843400.0       87
# 26353922.0      62
# 29127683.0      43
# 51842568.0      37
# 34006785.0      36
# 26368258.0      28
# 29127682.0      28
# 30829314.0      26
# 34006275.0      25
# 2828806.0       25
# 3952902.0       23
# 30827265.0      18
# 26360322.0       7
# 51447566.0       6
# 26365186.0       5
# 2568966.0        4
# 26353920.0       3
# Name: SCell_Cell_Identity, dtype: int64
#
# SCell_freq_MHz
# 2600.0    9326
# 1800.0     302
# Name: SCell_freq_MHz, dtype: int64
#
# operator
# 1    9473
# 2    8770
# Name: operator, dtype: int64
#
# Latitude
# 52.515177    388
# 52.515182    258
# 52.515180    249
# 52.491582    237
# 52.515185    199
#             ...
# 52.513308      1
# 52.506250      1
# 52.509698      1
# 52.516242      1
# 52.514178      1
# Name: Latitude, Length: 7121, dtype: int64
#
# Longitude
# 13.361338    265
# 13.361377    158
# 13.361245    152
# 13.361252    145
# 13.361375    140
#             ...
# 13.370283      1
# 13.341312      1
# 13.308823      1
# 13.334763      1
# 13.345588      1
# Name: Longitude, Length: 9797, dtype: int64
#
# Altitude
# 34.5    327
# 36.1    295
# 29.5    201
# 36.9    191
# 28.9    178
#        ...
# 12.8      1
# 2.5       1
# 3.3       1
# 0.9       1
# 19.2      1
# Name: Altitude, Length: 552, dtype: int64
#
# speed_kmh
# 0.0000     7855
# 34.6324      65
# 34.2620      61
# 30.1876      59
# 5.1856       59
#            ...
# 56.6712       1
# 62.4124       1
# 62.7828       1
# 58.3380       1
# 65.1904       1
# Name: speed_kmh, Length: 365, dtype: int64
#
# COG
# 169.8    1335
# 76.9      543
# 84.4      530
# 85.3      423
# 84.1      283
#          ...
# 22.4        1
# 61.3        1
# 294.1       1
# 276.4       1
# 88.5        1
# Name: COG, Length: 2397, dtype: int64
#
# precipIntensity
# 0.0000    3298
# 0.0655    1654
# 0.0132    1632
# 0.0081     544
# 0.0645     484
#           ...
# 0.0091      30
# 0.0459      17
# 0.0646      10
# 0.0413       1
# 0.0138       1
# Name: precipIntensity, Length: 79, dtype: int64
#
# precipProbability
# 0.01    7718
# 0.04    3894
# 0.02    3333
# 0.00    3298
# Name: precipProbability, dtype: int64
#
# temperature
# 18.13    2202
# 22.98    1598
# 23.87    1027
# 18.15    1017
# 19.31     897
#          ...
# 22.29      30
# 19.26      17
# 21.60       9
# 22.52       6
# 23.03       1
# Name: temperature, Length: 62, dtype: int64
#
# apparentTemperature
# 18.13    2202
# 22.98    1598
# 23.87    1027
# 18.15    1017
# 19.31     897
#          ...
# 22.29      30
# 19.26      17
# 21.60       9
# 22.52       6
# 23.03       1
# Name: apparentTemperature, Length: 62, dtype: int64
#
# dewPoint
# 14.08    1654
# 14.52    1598
# 14.71    1301
# 14.06     831
# 13.83     706
#          ...
# 14.00      21
# 13.30       4
# 14.20       4
# 13.85       2
# 14.51       1
# Name: dewPoint, Length: 69, dtype: int64
#
# humidity
# 0.77    3894
# 0.62    3130
# 0.70    2839
# 0.59    2679
# 0.57    2577
# 0.61    2230
# 0.60     345
# 0.69     269
# 0.73     225
# 0.63      30
# 0.58      21
# 0.55       4
# Name: humidity, dtype: int64
#
# pressure
# 1011.9    3894
# 1013.7    3547
# 1012.5    3108
# 1013.6    2859
# 1013.5    2424
# 1013.8    1804
# 1013.9     382
# 1012.2     225
# Name: pressure, dtype: int64
#
# windSpeed
# 4.06    3001
# 4.07    2095
# 2.29    1678
# 2.42     964
# 2.13     836
# 2.12     772
# 4.08     698
# 2.22     652
# 2.27     626
# 2.17     589
# 2.26     589
# 2.40     574
# 2.14     475
# 2.19     456
# 2.39     426
# 4.10     422
# 4.05     406
# 2.41     373
# 4.09     286
# 2.21     260
# 2.18     251
# 2.20     242
# 2.46     226
# 2.43     212
# 2.35     162
# 4.23     156
# 2.15     132
# 2.45     124
# 2.44     123
# 2.36     110
# 4.25      69
# 2.16      62
# 4.11      60
# 2.25      58
# 2.23      40
# 4.04      34
# 2.37       4
# Name: windSpeed, dtype: int64
#
# cloudCover
# 0.97    4078
# 0.95    3199
# 0.96    3010
# 0.82    2857
# 0.76    2581
# 0.83    1306
# 0.84     596
# 0.85     305
# 0.98     139
# 0.94      99
# 0.86      73
# Name: cloudCover, dtype: int64
#
# uvIndex
# 3.0    9031
# 4.0    6631
# 2.0    2581
# Name: uvIndex, dtype: int64
#
# visibility
# 16.093    18243
# Name: visibility, dtype: int64
#
# Traffic Jam Factor
# 3.14159    1850
# 0.00000     343
# 0.66687     271
# 0.34846     242
# 0.22096     242
#            ...
# 3.76766       1
# 2.69087       1
# 1.06542       1
# 1.04452       1
# 2.89917       1
# Name: Traffic Jam Factor, Length: 983, dtype: int64
#
# area
# Park           6908
# Residential    5455
# Avenue         3681
# Highway        2153
# Tunnel           46
# Name: area, dtype: int64

# %% [markdown]
# Analyse des variables quantitatives

# %%
train.select_dtypes(include='number').describe()
# Out:
#           timestamp  PCell_RSRP_max  PCell_RSRQ_max  PCell_RSSI_max  \
# count  3.427400e+04    34274.000000    34274.000000    34274.000000
# mean   1.624447e+09      -87.085767      -13.061258      -54.435712
# std    9.176344e+04       11.719533        2.463729       10.765029
# min    1.624348e+09     -175.605625      -24.774375      -87.852500
# 25%    1.624367e+09      -95.201562      -14.790000      -61.961719
# 50%    1.624377e+09      -86.845313      -12.681875      -53.992500
# 75%    1.624548e+09      -79.246719      -11.378252      -46.845156
# max    1.624554e+09      -55.550625       -5.389375      -13.032500
#
#        PCell_SNR_max  PCell_Downlink_Num_RBs  PCell_Downlink_Average_MCS  \
# count   34274.000000            34274.000000                34274.000000
# mean       11.861843            64089.078835                   19.973858
# std         7.414607            22991.689616                    5.054947
# min       -15.603000                4.000000                    0.000000
# 25%         6.431250            43724.000000                   17.000000
# 50%        12.171000            62785.000000                   21.000000
# 75%        17.579000            87828.000000                   24.000000
# max        28.622000           100471.000000                   28.000000
#
#        PCell_Downlink_bandwidth_MHz  PCell_Cell_Identity  PCell_freq_MHz  ...  \
# count                  33207.000000         3.320700e+04    34274.000000  ...
# mean                      19.233746         1.898801e+07     1926.737469  ...
# std                        1.898843         1.381858e+07      264.412295  ...
# min                        5.000000         2.567188e+06      900.000000  ...
# 25%                       20.000000         3.282957e+06     1800.000000  ...
# 50%                       20.000000         2.635878e+07     1800.000000  ...
# 75%                       20.000000         2.694707e+07     2000.000000  ...
# max                       20.000000         5.184258e+07     2600.000000  ...
#
#        apparentTemperature      dewPoint      humidity      pressure  \
# count         34274.000000  34274.000000  34274.000000  34274.000000
# mean             20.076148     13.952753      0.682186   1015.186410
# std               1.951120      0.462473      0.063657      2.377349
# min              18.130000     13.300000      0.550000   1011.900000
# 25%              18.670000     13.610000      0.620000   1013.500000
# 50%              18.880000     13.800000      0.710000   1013.800000
# 75%              21.610000     14.110000      0.730000   1017.700000
# max              23.880000     14.920000      0.770000   1018.000000
#
#           windSpeed    cloudCover       uvIndex    visibility  \
# count  34274.000000  34274.000000  34274.000000  3.427400e+04
# mean       2.613565      0.938075      2.564072  1.609300e+01
# std        0.756239      0.078149      1.023344  3.552766e-15
# min        1.960000      0.760000      1.000000  1.609300e+01
# 25%        2.160000      0.940000      2.000000  1.609300e+01
# 50%        2.290000      0.970000      3.000000  1.609300e+01
# 75%        2.430000      0.990000      3.000000  1.609300e+01
# max        4.250000      1.000000      4.000000  1.609300e+01
#
#        Traffic Jam Factor        target
# count        33946.000000  3.427400e+04
# mean             3.328803  5.550386e+07
# std              2.202747  4.319385e+07
# min              0.000000  4.800000e+04
# 25%              2.171180  2.400000e+07
# 50%              3.009460  4.240000e+07
# 75%              3.454510  7.200000e+07
# max              9.602590  2.710000e+08
#
# [8 rows x 38 columns]

# %% [markdown]
# Analyse des données manquantes

# %%
train.isnull().sum().sort_values(ascending=False) / train.shape[0] * 100
# Out:
# SCell_Cell_Identity             60.830367
# SCell_Downlink_bandwidth_MHz    60.830367
# SCell_Downlink_Average_MCS      46.504639
# SCell_Downlink_Num_RBs          46.504639
# SCell_freq_MHz                  44.529381
# SCell_RSRP_max                  44.529381
# SCell_SNR_max                   44.529381
# SCell_RSSI_max                  44.529381
# SCell_RSRQ_max                  44.529381
# PCell_Downlink_bandwidth_MHz     3.113147
# PCell_Cell_Identity              3.113147
# Traffic Jam Factor               0.956994
# Altitude                         0.020424
# precipProbability                0.000000
# temperature                      0.000000
# apparentTemperature              0.000000
# dewPoint                         0.000000
# area                             0.000000
# visibility                       0.000000
# uvIndex                          0.000000
# cloudCover                       0.000000
# windSpeed                        0.000000
# COG                              0.000000
# pressure                         0.000000
# humidity                         0.000000
# precipIntensity                  0.000000
# id                               0.000000
# speed_kmh                        0.000000
# Longitude                        0.000000
# Latitude                         0.000000
# operator                         0.000000
# timestamp                        0.000000
# PCell_freq_MHz                   0.000000
# PCell_Downlink_Average_MCS       0.000000
# PCell_Downlink_Num_RBs           0.000000
# PCell_SNR_max                    0.000000
# PCell_RSSI_max                   0.000000
# PCell_RSRQ_max                   0.000000
# PCell_RSRP_max                   0.000000
# device                           0.000000
# target                           0.000000
# dtype: float64

# %%
test.isnull().sum().sort_values(ascending=False) / test.shape[0] * 100
# Out:
# SCell_Cell_Identity             73.359645
# SCell_Downlink_bandwidth_MHz    73.359645
# SCell_Downlink_Average_MCS      51.252535
# SCell_Downlink_Num_RBs          51.252535
# SCell_freq_MHz                  47.223593
# SCell_RSRQ_max                  47.223593
# SCell_SNR_max                   47.223593
# SCell_RSSI_max                  47.223593
# SCell_RSRP_max                  47.223593
# Traffic Jam Factor               0.685194
# Altitude                         0.027408
# PCell_Downlink_Average_MCS       0.005482
# PCell_Downlink_Num_RBs           0.005482
# pressure                         0.000000
# humidity                         0.000000
# dewPoint                         0.000000
# COG                              0.000000
# windSpeed                        0.000000
# cloudCover                       0.000000
# uvIndex                          0.000000
# visibility                       0.000000
# apparentTemperature              0.000000
# temperature                      0.000000
# precipProbability                0.000000
# precipIntensity                  0.000000
# id                               0.000000
# speed_kmh                        0.000000
# Longitude                        0.000000
# Latitude                         0.000000
# operator                         0.000000
# timestamp                        0.000000
# PCell_freq_MHz                   0.000000
# PCell_Cell_Identity              0.000000
# PCell_Downlink_bandwidth_MHz     0.000000
# PCell_SNR_max                    0.000000
# PCell_RSSI_max                   0.000000
# PCell_RSRQ_max                   0.000000
# PCell_RSRP_max                   0.000000
# device                           0.000000
# area                             0.000000
# dtype: float64

# %% [markdown]
# ### 1.2. Analyse du fond

# %%
def timestamp_to_datetime(timestamp) -> dt:
    ''' convertit un entier timestamp de secondes en Datetime
    '''
    return dt.fromtimestamp(timestamp)

# %%
train1 = train.copy()
test1 = test.copy()
train1['timestamp'] = train1['timestamp'].apply(timestamp_to_datetime)
test1['timestamp'] = test1['timestamp'].apply(timestamp_to_datetime)
train1.set_index('timestamp', inplace=True)
test1.set_index('timestamp', inplace=True)
display(train1.head(3), test1.head(3))
# Out:
#                                 id device  PCell_RSRP_max  PCell_RSRQ_max  \
# timestamp
# 2021-06-22 13:03:28  Id_qt2qn56050    pc1      -84.498750      -14.586875
# 2021-06-22 14:34:25  Id_f1zf07cwb6    pc3      -86.818125      -11.982500
# 2021-06-22 14:24:31  Id_uoxdz7di5b    pc3     -101.916250      -13.257500
#
#                      PCell_RSSI_max  PCell_SNR_max  PCell_Downlink_Num_RBs  \
# timestamp
# 2021-06-22 13:03:28      -49.855625         16.457                 35076.0
# 2021-06-22 14:34:25      -54.838125         16.674                 42704.0
# 2021-06-22 14:24:31      -71.241250          9.392                 36017.0
#
#                      PCell_Downlink_Average_MCS  PCell_Downlink_bandwidth_MHz  \
# timestamp
# 2021-06-22 13:03:28                        23.0                          20.0
# 2021-06-22 14:34:25                        24.0                          20.0
# 2021-06-22 14:24:31                        22.0                          20.0
#
#                      PCell_Cell_Identity  ...  dewPoint  humidity  pressure  \
# timestamp                                 ...
# 2021-06-22 13:03:28           26368258.0  ...     13.86      0.62    1013.6
# 2021-06-22 14:34:25            2568970.0  ...     14.52      0.59    1013.5
# 2021-06-22 14:24:31            2824458.0  ...     14.71      0.61    1013.8
#
#                      windSpeed  cloudCover  uvIndex  visibility  \
# timestamp
# 2021-06-22 13:03:28       2.39        0.95      4.0      16.093
# 2021-06-22 14:34:25       2.29        0.82      3.0      16.093
# 2021-06-22 14:24:31       2.13        0.82      3.0      16.093
#
#                      Traffic Jam Factor         area      target
# timestamp
# 2021-06-22 13:03:28             0.38979  Residential  51500000.0
# 2021-06-22 14:34:25             3.78322  Residential  50300000.0
# 2021-06-22 14:24:31             2.08425  Residential  16500000.0
#
# [3 rows x 40 columns]
#                                 id device  PCell_RSRP_max  PCell_RSRQ_max  \
# timestamp
# 2021-06-22 15:02:59  Id_ln0e0hfrgx    pc2      -97.121875      -12.923750
# 2021-06-22 12:51:04  Id_svf7nz9fxv    pc4      -65.202500       -9.944375
# 2021-06-22 15:29:55  Id_ww2mh07gwj    pc2      -79.298125      -17.468750
#
#                      PCell_RSSI_max  PCell_SNR_max  PCell_Downlink_Num_RBs  \
# timestamp
# 2021-06-22 15:02:59      -87.554375         13.293                 39276.0
# 2021-06-22 12:51:04      -35.501875         21.823                 39566.0
# 2021-06-22 15:29:55      -74.823750         24.114                 41900.0
#
#                      PCell_Downlink_Average_MCS  PCell_Downlink_bandwidth_MHz  \
# timestamp
# 2021-06-22 15:02:59                        24.0                            20
# 2021-06-22 12:51:04                        25.0                            20
# 2021-06-22 15:29:55                        27.0                            20
#
#                      PCell_Cell_Identity  ...  apparentTemperature  dewPoint  \
# timestamp                                 ...
# 2021-06-22 15:02:59            3499534.0  ...                23.05     14.55
# 2021-06-22 12:51:04           26358784.0  ...                21.56     13.92
# 2021-06-22 15:29:55            2843400.0  ...                22.93     14.65
#
#                      humidity  pressure  windSpeed  cloudCover  uvIndex  \
# timestamp
# 2021-06-22 15:02:59      0.59    1013.6       2.27        0.83      3.0
# 2021-06-22 12:51:04      0.62    1013.6       2.42        0.95      4.0
# 2021-06-22 15:29:55      0.60    1013.5       2.26        0.85      3.0
#
#                      visibility  Traffic Jam Factor    area
# timestamp
# 2021-06-22 15:02:59      16.093             3.07702  Avenue
# 2021-06-22 12:51:04      16.093             0.66000    Park
# 2021-06-22 15:29:55      16.093             2.49330    Park
#
# [3 rows x 39 columns]

# %% [markdown]
# Analyse et visualisation de la target

# %%
plt.figure(figsize=(13,5))
train1['target'].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %% [markdown]
# Analyse des outliers

# %%
# Check for outliers in the target variable
plt.figure(figsize=(10, 4))
plt.grid()
plt.xticks(np.arange(0, 100, 5))
sns.boxplot(x=train['target'])
plt.title('Boxplot showing outliers - target variable')
plt.show()

# %% [markdown]
# #### Compréhension des diffiérentes variables

# %%
variable_definitions # schema de definition des variables
# Out:
#                     VARIABLENAME  \
# 0                             id
# 1                      timestamp
# 2                         device
# 3                 PCell_RSRP_max
# 4                 PCell_RSRQ_max
# 5                 PCell_RSSI_max
# 6                  PCell_SNR_max
# 7         PCell_Downlink_Num_RBs
# 8         PCell_Downlink_TB_Size
# 9     PCell_Downlink_Average_MCS
# 10  PCell_Downlink_bandwidth_MHz
# 11           PCell_Cell_Identity
# 12                PCell_freq_MHz
# 13                SCell_RSRP_max
# 14                SCell_RSRQ_max
# 15                SCell_RSSI_max
# 16                 SCell_SNR_max
# 17        SCell_Downlink_Num_RBs
# 18        SCell_Downlink_TB_Size
# 19    SCell_Downlink_Average_MCS
# 20  SCell_Downlink_bandwidth_MHz
# 21           SCell_Cell_Identity
# 22                SCell_freq_MHz
# 23                      operator
# 24                      Latitude
# 25                     Longitude
# 26                      Altitude
# 27                     speed_kmh
# 28                           COG
# 29               precipIntensity
# 30             precipProbability
# 31                   temperature
# 32           apparentTemperature
# 33                      dewPoint
# 34                      humidity
# 35                      pressure
# 36                     windSpeed
# 37                    cloudCover
# 38                       uvIndex
# 39                    visibility
# 40            Traffic Jam Factor
# 41                          area
# 42                        target
#
#                                  VARIABLE DESCRIPTION
# 0                              Unique ID for each row
# 1                           Unix timestamp in seconds
# 2                   ID of the vehicle carrying the UE
# 3   Maximum reference signal received power in dBm...
# 4   Maximum reference signal received quality in d...
# 5   Maximum received signal strength indicator in ...
# 6   Maximum signal to noise ratio in dB from the p...
# 7   Aggregated number of received resource blocks ...
# 8   Aggregated transport block size in downlink fr...
# 9   Average modulation and coding scheme weighted ...
# 10    Downlink bandwidth in MHz from the primary cell
# 11                       Cell ID of the primary cell
# 12       Carrier frequency in MHz of the primary cell
# 13  Maximum reference signal received power in dBm...
# 14  Maximum reference signal received quality in d...
# 15  Maximum received signal strength indicator in ...
# 16  Maximum signal to noise ratio in dB from the s...
# 17  Aggregated number of received resource blocks ...
# 18  Aggregated transport block size in downlink fr...
# 19  Average modulation and coding scheme weighted ...
# 20  Downlink bandwidth in MHz from the secondary cell
# 21                     Cell ID of the secondary cell
# 22     Carrier frequency in MHz of the secondary cell
# 23                                 ID of the operator
# 24                        GPS latitude of the vehicle
# 25                       GPS longitude of the vehicle
# 26                        GPS altitude of the vehicle
# 27             GPS-based speed of the vehicle in km/h
# 28        GPS-based course over ground of the vehicle
# 29                            Precipitation intensity
# 30                          Precipitation probability
# 31                                        Temperature
# 32                               Apparent temperature
# 33                                          Dew point
# 34                                           Humidity
# 35                               Atmospheric pressure
# 36                                         Wind speed
# 37                                        Cloud cover
# 38                                  Ultraviolet index
# 39               Visibility due to weather conditions
# 40  Factor of traffic congestion (a higher factor ...
# 41  Categorical urban area among Avenue/Park/Resid...
# 42  Prediction target: downlink datarate in bits p...

# %% [markdown]
# ## 2. Preprocessing

# %% [markdown]
# Data preprocessing function

# %%
def preprocessing_data(data: pd.DataFrame) -> pd.DataFrame:
    ''' Réalise la phase de pré-traitement d'un dataset à savoir l'encodage 
    des variables discrètes et la normalisation de toutes les variables 
    '''
    data2 = data.copy()
    try:
        data1 = data.drop([ID, 'timestamp', TARGET], axis=1)
    except:
        data1 = data.drop([ID, 'timestamp'], axis=1)
    # la liste des colonnes discrètes
    object_columns = list(
        data1.select_dtypes(include='object').columns)
    # encodage des variables discrètes
    encoder = OrdinalEncoder()
    data1[object_columns] = encoder.fit_transform(data1[object_columns])

    data2[data1.columns] = data1
    data2.drop('timestamp', axis=1, inplace=True)
    return data2

# %%
train_pp = preprocessing_data(train)
test_pp = preprocessing_data(test)
test_pp.head()
# Out:
#               id  device  PCell_RSRP_max  PCell_RSRQ_max  PCell_RSSI_max  \
# 0  Id_ln0e0hfrgx     0.0      -97.121875      -12.923750      -87.554375
# 1  Id_svf7nz9fxv     1.0      -65.202500       -9.944375      -35.501875
# 2  Id_ww2mh07gwj     0.0      -79.298125      -17.468750      -74.823750
# 3  Id_v88r4y03ww     0.0     -110.128125      -13.513750      -92.566875
# 4  Id_2u4y4kzglh     0.0     -117.451250      -18.753125      -93.048125
#
#    PCell_SNR_max  PCell_Downlink_Num_RBs  PCell_Downlink_Average_MCS  \
# 0         13.293                 39276.0                        24.0
# 1         21.823                 39566.0                        25.0
# 2         24.114                 41900.0                        27.0
# 3          6.282                 76310.0                        18.0
# 4         -5.767                 44887.0                         7.0
#
#    PCell_Downlink_bandwidth_MHz  PCell_Cell_Identity  ...  \
# 0                            20            3499534.0  ...
# 1                            20           26358784.0  ...
# 2                            20            2843400.0  ...
# 3                            20            3499534.0  ...
# 4                            20            3282957.0  ...
#
#    apparentTemperature  dewPoint  humidity  pressure  windSpeed  cloudCover  \
# 0                23.05     14.55      0.59    1013.6       2.27        0.83
# 1                21.56     13.92      0.62    1013.6       2.42        0.95
# 2                22.93     14.65      0.60    1013.5       2.26        0.85
# 3                22.95     14.45      0.59    1013.6       2.27        0.82
# 4                23.05     14.55      0.59    1013.6       2.27        0.83
#
#    uvIndex  visibility  Traffic Jam Factor  area
# 0      3.0      16.093             3.07702   0.0
# 1      4.0      16.093             0.66000   2.0
# 2      3.0      16.093             2.49330   2.0
# 3      3.0      16.093             5.74454   1.0
# 4      3.0      16.093             3.48651   0.0
#
# [5 rows x 39 columns]

# %%
train_pp.head()
# Out:
#               id  device  PCell_RSRP_max  PCell_RSRQ_max  PCell_RSSI_max  \
# 0  Id_qt2qn56050     0.0      -84.498750      -14.586875      -49.855625
# 1  Id_f1zf07cwb6     1.0      -86.818125      -11.982500      -54.838125
# 2  Id_uoxdz7di5b     1.0     -101.916250      -13.257500      -71.241250
# 3  Id_hzn8nj29gu     0.0      -95.598750      -14.696250      -61.660000
# 4  Id_2kfrccrfiw     0.0      -97.735000      -14.867500      -63.170625
#
#    PCell_SNR_max  PCell_Downlink_Num_RBs  PCell_Downlink_Average_MCS  \
# 0         16.457                 35076.0                        23.0
# 1         16.674                 42704.0                        24.0
# 2          9.392                 36017.0                        22.0
# 3         10.726                 95955.0                        17.0
# 4         10.889                 83062.0                        19.0
#
#    PCell_Downlink_bandwidth_MHz  PCell_Cell_Identity  ...  dewPoint  humidity  \
# 0                          20.0           26368258.0  ...     13.86      0.62
# 1                          20.0            2568970.0  ...     14.52      0.59
# 2                          20.0            2824458.0  ...     14.71      0.61
# 3                          20.0           26367489.0  ...     13.43      0.71
# 4                          20.0           26369024.0  ...     13.46      0.71
#
#    pressure  windSpeed  cloudCover  uvIndex  visibility  Traffic Jam Factor  \
# 0    1013.6       2.39        0.95      4.0      16.093             0.38979
# 1    1013.5       2.29        0.82      3.0      16.093             3.78322
# 2    1013.8       2.13        0.82      3.0      16.093             2.08425
# 3    1017.9       1.97        0.99      3.0      16.093             8.80702
# 4    1017.9       1.97        0.99      3.0      16.093             2.21843
#
#    area      target
# 0   3.0  51500000.0
# 1   3.0  50300000.0
# 2   3.0  16500000.0
# 3   0.0  46400000.0
# 4   2.0  50200000.0
#
# [5 rows x 40 columns]

# %% [markdown]
# ## 3. Modelling

# %% [markdown]
# Evaluation function

# %%
def rmse(y_test, y_pred) -> float:
	''' returns the root mean squared error of a model
	'''
	return mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# Splitting

# %%
# Selecting the independent variables and the target variable
X = train_pp.drop([ID, TARGET], axis = 1)
# X = train_pp
y = train_pp[TARGET]
# spliting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %% [markdown]
# ### Fitting

# %% [markdown]
# Catboost model parameters

# %%
params = {
    'n_estimators': 3000,
    'learning_rate': 0.1,
    'objective': 'RMSE',
    'rsm': 0.6,
    'random_seed': 2,
    'early_stopping_rounds': 200,
    'use_best_model': True,
}

# %%
CB = CatBoostRegressor(**params)
model_cb = CB
model_cb.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=300)
y_pred_cb = model_cb.predict(X_test)
print(f'RMSE Score: {rmse(y_test, y_pred_cb)}')
# Out:
# 0:	learn: 39866864.4616809	test: 40757011.3647380	best: 40757011.3647380 (0)	total: 13.4ms	remaining: 40.2s
# 300:	learn: 8595268.3546057	test: 9609363.9052999	best: 9609363.9052999 (300)	total: 1.93s	remaining: 17.3s
# 600:	learn: 7458432.3078829	test: 9165242.6387176	best: 9164077.4275089 (598)	total: 3.87s	remaining: 15.4s
# 900:	learn: 6761791.2377416	test: 8974824.9855853	best: 8974824.9855853 (900)	total: 5.83s	remaining: 13.6s
# 1200:	learn: 6266331.2916953	test: 8877428.7375593	best: 8877390.9908681 (1196)	total: 7.79s	remaining: 11.7s
# 1500:	learn: 5848233.1330291	test: 8807667.9642727	best: 8807655.8406733 (1493)	total: 9.89s	remaining: 9.87s
# 1800:	learn: 5498342.8613864	test: 8768003.7259455	best: 8768003.7259455 (1800)	total: 11.9s	remaining: 7.89s
# 2100:	learn: 5207228.9478204	test: 8743198.0696939	best: 8741733.6533314 (2096)	total: 13.8s	remaining: 5.92s
# 2400:	learn: 4943899.4861196	test: 8719947.2330363	best: 8719947.2330363 (2400)	total: 16.4s	remaining: 4.08s
# 2700:	learn: 4710423.3848333	test: 8705402.3939024	best: 8705402.3939024 (2700)	total: 19.2s	remaining: 2.13s
# 2999:	learn: 4492542.9682184	test: 8699630.7253748	best: 8696418.2138439 (2900)	total: 21.8s	remaining: 0us
#
# bestTest = 8696418.214
# bestIteration = 2900
#
# Shrink model to first 2901 iterations.
# RMSE Score: 8696418.21384391

# %% [markdown]
# RMSE Score: 8827461.907147136

# %% [markdown]
# RMSE Score: 8709491.172538169

# %% [markdown]
# ### Compréhension du modèle

# %%
plt.figure(figsize=(10,9))
model = model_cb
plt.barh(X_test.columns.to_list(), pd.Series(model.feature_importances_).sort_values())
# Out:
# <BarContainer object of 38 artists>

# %% [markdown]
# Niveaux d'importance des features pris en compte par le modèle

# %%
model = model_cb
model.feature_importances_[model.feature_importances_ > 0].size
# Out:
# 37

# %% [markdown]
# Analyse des prédictions

# %%
pred_errors: pd.DataFrame = X_test.copy()
pred_errors[TARGET] = y_test
pred_errors['prediction'] = y_pred_cb
pred_errors['error'] = abs(pred_errors['prediction'] - pred_errors[TARGET])
pred_errors = pred_errors[[TARGET, 'prediction', 'error']]
pred_errors.sort_values(by='error', ascending=False, inplace=True)
pred_errors
# Out:
#             target    prediction         error
# 2375    44800000.0  1.149491e+08  7.014907e+07
# 13078  134000000.0  6.969652e+07  6.430348e+07
# 2000   157000000.0  9.295236e+07  6.404764e+07
# 13978   78800000.0  1.386987e+08  5.989871e+07
# 22476  119000000.0  6.008479e+07  5.891521e+07
# ...            ...           ...           ...
# 9372    46000000.0  4.599788e+07  2.117944e+03
# 27995   24000000.0  2.399857e+07  1.432578e+03
# 17612   49900000.0  4.989884e+07  1.163020e+03
# 23252   16500000.0  1.649908e+07  9.161491e+02
# 21324   21300000.0  2.130060e+07  6.022005e+02
#
# [6855 rows x 3 columns]

# %%
pred_errors.error.sum()
# Out:
# 37868852497.356865

# %% [markdown]
# ## Submission

# %%
sample_submission.head()
# Out:
#               id  target
# 0  Id_hg4i94kfbg     0.0
# 1  Id_j1afeth58t     0.0
# 2  Id_bahkipht8j     0.0
# 3  Id_t1iry5orn0     0.0
# 4  Id_dnlh2w774v     0.0

# %%
# Make prediction on the test set
test_df = test_pp.drop([ID], axis=1)
predictions = model_cb.predict(test_df)

# Create a submission file
sub_file = pd.DataFrame({ID: test[ID], TARGET: predictions})
sub_file.head()
# Out:
#               id        target
# 0  Id_ln0e0hfrgx  2.098061e+07
# 1  Id_svf7nz9fxv  5.767991e+07
# 2  Id_ww2mh07gwj  8.064313e+07
# 3  Id_v88r4y03ww  2.023988e+07
# 4  Id_2u4y4kzglh  3.659230e+06

# %%
# Create file
today = dt.now().strftime(format="%Y-%m-%d_%Hh%M")
sub_file.to_csv(f'submissions/submission_{today}.csv', index=False)

# %% [markdown]
# ## Saving model

# %%
# Save the model as a pickle in a file
model = model_cb
filename = 'catboost_public_9903776.468'
joblib.dump(model, f'models/{filename}.pkl')
# Out:
# ['models/catboost_public_9903776.468.pkl']
